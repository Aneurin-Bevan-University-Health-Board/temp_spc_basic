# %% [markdown]
# # SPC Exploration
# Use this notebook to explore your data and run SPC charts interactively.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from src.excel_loader import load_excel

# df = load_excel('data/input/your_file.xlsx')
# print(df.head())
